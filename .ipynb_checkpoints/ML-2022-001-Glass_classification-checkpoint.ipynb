# %% [markdown]
# # Table of contents
# - [1 - Introduction](#chapter1)
# - [2 - Loading libraries and data exploration](#chapter2)
# - [3 - Data Cleaning](#chapter3)
# - [4 - Models](#chapter4)
# - [5 - Results](#chapter5)

# %% [markdown]
# # 0 - Abstract

# %% [markdown]
# A summary of findings/discoveries and results.

# %% [markdown]
# # 1 - Introduction <a class="anchor" id="chapter1"></a>

# %% [markdown]
# The purpose of this study is to define the type of a glass depending on the given features. 6 types of glass; defined in terms of their oxide content (i.e. Na, Fe, K, etc) and refractive index (RI). There are originally seven type of glasses but type-4 is omitted from the data set hence there are six type of glass in the data set.
#
# The motivation behind the glass classification is given by the contributor as;
# >The study of classification of types of glass was motivated by
# criminological investigation. At the scene of the crime, the glass left
# can be used as evidence…if it is correctly identified!
#
# The data set used in this work is obtained from;
# - https://archive.ics.uci.edu/ml/datasets/Glass+Identification
# - https://www.kaggle.com/datasets/uciml/glass
#
# Columns names and also the ingredients are:
# - RI: refractive index
# - Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# - Mg: Magnesium
# - Al: Aluminum
# - Si: Silicon
# - K: Potassium
# - Ca: Calcium
# - Ba: Barium
# - Fe: Iron
# - Type of glass: (class attribute)
#     - 1 building*windows*float*processed*
#     - 2 building*windows*non*float*processed
#     - 3 vehicle*windows*float*processed*
#     - ~~4 vehicle*windows*non*float*processed~~ (none in this database)
#     - 5 containers
#     - 6 tableware
#     - 7 headlamps
#
# Questions by the contributor:
# >Data exploration of this dataset reveals two important characteristics :
# >1) The variables are highly corelated with each other including the response variables:
# >So which kind of ML algorithm is most suitable for this dataset Random Forest , KNN or other? Also since dataset is too small is there any chance of applying PCA or it should be completely avoided?
# >
# >2) Highly Skewed Data:
# >Is scaling sufficient or are there any other techniques which should be applied to normalize data? Like BOX-COX Power transformation?

# %% [markdown]
# # 2 - Loading libraries and data exploration <a class="anchor" id="chapter2"></a>

# %% [markdown]
# ## 2.1 Loading libraries and packages to be used

# %%
# ! pip install <package name>

# %%
import warnings
warnings.filterwarnings('ignore') # there were warnings in columns histograms

import pandas as pd # To read the data set and data preprocessing.
import numpy as np #
from sklearn.feature_selection import mutual_info_classif # to measure associations between features and the target. 
from collections import Counter # for the outlier hunt
from mlxtend.preprocessing import minmax_scaling # for min_max scaling
# from sklearn.preprocessing import (StandardScaler, # Standardise the objects, converts to a normal distribution curve
#                                    MinMaxScaler, # changes the values to be between 0 and 1
#                                    FunctionTransformer) 

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns #
from scipy import stats # for Box-Cox Transformation
# %matplotlib inline

# Modeling
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import (train_test_split, cross_val_score, GridSearchCV) #, 
                                     #KFold, StratifiedKFold, learning_curve, validation_curve)
from sklearn.metrics import accuracy_score

from sklearn.pipeline import Pipeline

# %%
glass = pd.read_csv('Data/glass.csv') # importing the dataset
glass.shape
print('This data set is consistent of',glass.shape[0], 'observations and', glass.shape[1], 'columns.')
# Out:
# This data set is consistent of 214 observations and 10 columns.

# %% [markdown]
# Since the target variable is given, it won't be a problem to assign features early.

# %%
target = 'Type'
features = glass.drop([target], axis=1).columns.tolist()

features
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']

# %%
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
#df.tail()

# %% [markdown]
# The values of the oxide content is already given in percentages and all variables except `RI` share the same measurement units. It looks like that there is no need of scaling here. **BUT** one should also check further statistical values i.e. `minimum` and `maximum` values, and boxplots before making scaling decisions.

# %%
glass[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
# dtypes: float64(9)
# memory usage: 15.2 KB

# %%
glass.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# A glimpse of central tendencies:

# %%
glass[features].describe().T
# Out:
#     count       mean       std       min        25%       50%        75%  \
# RI  214.0   1.518365  0.003037   1.51115   1.516522   1.51768   1.519157
# Na  214.0  13.407850  0.816604  10.73000  12.907500  13.30000  13.825000
# Mg  214.0   2.684533  1.442408   0.00000   2.115000   3.48000   3.600000
# Al  214.0   1.444907  0.499270   0.29000   1.190000   1.36000   1.630000
# Si  214.0  72.650935  0.774546  69.81000  72.280000  72.79000  73.087500
# K   214.0   0.497056  0.652192   0.00000   0.122500   0.55500   0.610000
# Ca  214.0   8.956963  1.423153   5.43000   8.240000   8.60000   9.172500
# Ba  214.0   0.175047  0.497219   0.00000   0.000000   0.00000   0.000000
# Fe  214.0   0.057009  0.097439   0.00000   0.000000   0.00000   0.100000
#
#          max
# RI   1.53393
# Na  17.38000
# Mg   4.49000
# Al   3.50000
# Si  75.41000
# K    6.21000
# Ca  16.19000
# Ba   3.15000
# Fe   0.51000

# %% [markdown]
# Duplicated row detection.

# %%
duplicated_row = glass[glass.duplicated(keep = 'first')]
duplicated_row
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
glass.iloc[37:41]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 37  1.51797  12.74  3.48  1.35  72.96  0.64  8.68  0.0  0.0     1
# 38  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1
# 40  1.51793  12.79  3.50  1.12  73.03  0.64  8.77  0.0  0.0     1

# %% [markdown]
# As seen above, entries 38 and 39 are the exact same. It would be beneficial to get rid of the duplicated entries early for the sake of analysing clearity.

# %%
glass.drop(index = duplicated_row.index, 
           axis = 0, 
           inplace = True
          )
glass.iloc[37:41]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 37  1.51797  12.74  3.48  1.35  72.96  0.64  8.68  0.0  0.0     1
# 38  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1
# 40  1.51793  12.79  3.50  1.12  73.03  0.64  8.77  0.0  0.0     1
# 41  1.51755  12.71  3.42  1.20  73.20  0.59  8.64  0.0  0.0     1

# %% [markdown]
# ## 2.2 Data Visualisation

# %% [markdown]
# As it is described by the contributor, the data set is consistent of only numerical data. Additionally there are no missing data, so we don't need to deal with missing values during data cleaning.
#
# It will be helpful to make histograms to understand the distributions, plot the correlations to observe the relationship between the variables, and observe the boxplots of the features. Since the unit measurement of the oxides are given in percentages, it is not meaningful to make a pivot table this time.

# %% [markdown]
# As mentioned before and after checking further statistical values; `min` & `max` values of `Si` implies that we should strongly consider scaling.

# %%
glass[features].var()
# Out:
# RI    0.000009
# Na    0.666937
# Mg    2.084244
# Al    0.245942
# Si    0.599073
# K     0.426651
# Ca    2.033138
# Ba    0.248248
# Fe    0.009524
# dtype: float64

# %% [markdown]
# Cardinality check

# %%
# Since there are no non-numeric variables, it is not needed to check the cardinality of the data set.

# glass.nunique() #To evaluate the cardinality of non-numeric columns

# %%
# plt.figure(figsize=(10,10))
sns.countplot(x='Type', data=glass, order=glass['Type'].value_counts().index, palette='jet_r');

# %%
glass.Type.unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %% [markdown]
# With the low number of features, it is possible to examine them via making histograms of each one. For larger data sets it is a big hurdle.\
# One can use `df.skew()` to see a numeric summary of skewness for data sets consisted of larger number of features.

# %%
for col in glass[features]:
    fig, axes=plt.subplots(figsize=(5, 2), nrows=1, ncols=2)
    skew = glass[col].skew()
    sns.histplot(glass[col], ax=axes[0])
    sns.distplot(glass[col], ax=axes[1], fit=stats.norm, label = 'Skew = %.3f' %(skew))
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# Features RI, Mg, K, Ca, Ba, and Fe are highly; Al and Si are moderately; and Na is approximately skewed, normalization might be required.

# %% [markdown]
# One should inspect if there is any categorical variables.

# %%
# Get list of categorical variables
s = (glass.dtypes == 'object')
object_cols = list(s[s].index)

if len(object_cols) == 0:
    print('The data frame does not include categorical variables.')
else:
    print("Categorical variables are:", object_cols)
# Out:
# The data frame does not include categorical variables.

# %% [markdown]
# What is the relationship between the variables?

# %%
correlation = glass[features].corr()

#sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
#plt.figure(figsize=(10,10))
f, ax = plt.subplots(figsize = (10,10))
sns.heatmap(correlation, cbar = True,  square = True, annot=True, fmt= '.2f', annot_kws={'size': 10},
           ax = ax, cmap= 'seismic')# xticklabels= glass.columns, yticklabels= features) #, alpha = 0.7)
plt.show()

# %% [markdown]
# It seems like there is a highly positive correlation between RI and Ca. Lets do some plots of them.

# %%
sns.pairplot(glass, vars= ['RI','Ca'])
plt.show()

# %%
sns.relplot(x='RI', y='Ca', hue = 'Type', data = glass, palette='jet_r', s=50);

# %% [markdown]
# The heat map and scatter plots above shows that there is a strong relationship between RI and Ca. This indicates that it is worth gaining some domain information to understand these features' relationship better.
#
# After I made a small research to gain some domain information, I came across Britannica's article about glass. Under the ["Commercial glass composition"](https://www.britannica.com/technology/glass#ref283824) section calcium oxide (CaO) is mentioned as:
# >The addition of lime (calcium oxide, or CaO), supplied by the limestone, renders the glass insoluble again, **but too much makes a glass prone to devitrification**—i.e., the precipitation of crystalline phases in certain ranges of temperature. The optimum composition is about 75 percent silica, **10 percent lime**, and 15 percent soda, but **even this is too liable to devitrification** during certain mechanical forming operations to be satisfactory.
#
# Recall that Ca varies between 5.43 and 16.19. In these terms, correlation between RI and Ca is meaningful and implies a causal relationship between them.

# %%
print('Ca min: ', glass.Ca.min(), '\nCa max:',glass.Ca.max())
# Out:
# Ca min:  5.43
# Ca max: 16.19

# %% [markdown]
# Let's check the mutual information. Code below is taken and editted from Kaggle's [mutual information](https://www.kaggle.com/code/ryanholbrook/mutual-information) course.

# %%
def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(glass[features], glass['Type'], 'auto')
mi_scores#[::3]  # show a few features with their MI scores
# Out:
# Al    0.413329
# Mg    0.393224
# RI    0.351093
# K     0.320801
# Ba    0.315215
# Na    0.287083
# Ca    0.243137
# Si    0.077517
# Fe    0.076563
# Name: MI Scores, dtype: float64

# %%
# Glass types across the features 
# pd.pivot_table(glass, index = 'Type', values = glass.drop('Type', axis=1).columns.tolist())

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = glass[features], orient = 'h');

# %% [markdown]
# One would also like to check the fetures closer, for this I omitted `Si` to have a better view of other features.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = glass[['RI','Na','Mg','Al','K','Ca','Ba','Fe']], orient = 'h');

# %% [markdown]
# Due to the nature of glass components, ratio of `Si` is significantly higher than other components and varies in a similar range. Since all the components' measurement unit is same, there might be no need to apply scaling, but there is still a chance that scaling would improve the performance of the scale sensitive algorithms.
#
# From [ISLRv2](https://www.statlearning.com/) page 533:
# >...it is important to standardize the variables to have mean zero and standard deviation one before performing
# PCA.

# %% [markdown]
# `Si` omitted box-plot shows us that there are some big outliers in features such as `K` and `Na` and multiple outliers in all features except `Mg`. To detect all of the outliers, one can benefit from `Z-scores`. As 99.7% of the data points lie between +/- 3 standard deviation, treshold value is choosen as 3. Below the code returns `True` for the observations that have more than one outlier.

# %%
treshold = 3
z = np.abs(stats.zscore(glass[features]))
outliers = np.where(z > treshold)

obs_w_multi_outliers = pd.DataFrame(outliers[0][:]).value_counts()>=2
obs_w_multi_outliers
# Out:
# 105     True
# 106     True
# 162     True
# 170     True
# 183     True
# 111     True
# 200     True
# 171     True
# 206    False
# 202    False
# 188    False
# 187    False
# 104    False
# 173    False
# 161    False
# 144    False
# 130    False
# 110    False
# 109    False
# 212    False
# dtype: bool

# %%
# sns.pairplot(glass);

# %% [markdown]
# # 3 - Data Celaning <a class="anchor" id="chapter3"></a>

# %% [markdown]
# As seen from EDA section;
# - There isn't any missing value.
# - There was one duplicated entry and it is excluded friom the data set.
# - There were outliers in multiple features, the rows consistent of multuiple outliers are excluded.
# - High level skeweness in multiple features, normalization would require to increase the performance of normalisation sensitive algorithms such as LDA or any "Gaussian" methods.
# - Oxide contents to be scaled between 0-1 instead of 0-100 since they are in percentages.

# %% [markdown]
# ## 3.1 - Droping Outliers

# %%
glass_outs_dropped = glass.copy()
glass_outs_dropped.drop(index = [105,106,111,162,170,171,183,200], 
                       axis = 0, 
                       inplace = True
                      )
glass_outs_dropped.iloc[103:113]
# Out:
#           RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  Type
# 104  1.52410  13.83  2.90  1.17  71.15  0.08  10.79  0.0  0.00     2
# 107  1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.0  0.24     2
# 108  1.52222  14.43  0.00  1.00  72.67  0.10  11.52  0.0  0.08     2
# 109  1.51818  13.72  0.00  0.56  74.45  0.00  10.99  0.0  0.00     2
# 110  1.52664  11.23  0.00  0.77  73.21  0.00  14.68  0.0  0.00     2
# 112  1.52777  12.64  0.00  0.67  72.02  0.06  14.40  0.0  0.00     2
# 113  1.51892  13.46  3.83  1.26  72.55  0.57   8.21  0.0  0.14     2
# 114  1.51847  13.10  3.97  1.19  72.44  0.60   8.43  0.0  0.00     2
# 115  1.51846  13.41  3.89  1.33  72.38  0.51   8.28  0.0  0.00     2
# 116  1.51829  13.24  3.90  1.41  72.33  0.55   8.31  0.0  0.10     2

# %% [markdown]
# ## 3.2 - Scaling Oxide Contents

# %% [markdown]
# The purpose of the cell below is to set the oxide contents between 0-1 instead of 0-100.

# %%
glass_RI = glass_outs_dropped.iloc[:,:1].copy() # Copy 'RI' column w/o scaling.
glass_Type = glass_outs_dropped.iloc[:,-1:].copy() # Copy 'Type' column w/o scaling.
    
for feature in features[1:]: # Scaling other features b/w 0-1.
    df_scaled = glass_outs_dropped.iloc[:,1:9].div(100)#.round(2)
    
glass_oc_scaled = pd.concat([glass_RI.reset_index(drop=True), 
                          df_scaled.reset_index(drop=True), 
                          glass_Type.reset_index(drop=True)], 
                         axis=1)
glass_oc_scaled
# Out:
#           RI      Na      Mg      Al      Si       K      Ca      Ba   Fe  \
# 0    1.52101  0.1364  0.0449  0.0110  0.7178  0.0006  0.0875  0.0000  0.0
# 1    1.51761  0.1389  0.0360  0.0136  0.7273  0.0048  0.0783  0.0000  0.0
# 2    1.51618  0.1353  0.0355  0.0154  0.7299  0.0039  0.0778  0.0000  0.0
# 3    1.51766  0.1321  0.0369  0.0129  0.7261  0.0057  0.0822  0.0000  0.0
# 4    1.51742  0.1327  0.0362  0.0124  0.7308  0.0055  0.0807  0.0000  0.0
# ..       ...     ...     ...     ...     ...     ...     ...     ...  ...
# 200  1.51623  0.1414  0.0000  0.0288  0.7261  0.0008  0.0918  0.0106  0.0
# 201  1.51685  0.1492  0.0000  0.0199  0.7306  0.0000  0.0840  0.0159  0.0
# 202  1.52065  0.1436  0.0000  0.0202  0.7342  0.0000  0.0844  0.0164  0.0
# 203  1.51651  0.1438  0.0000  0.0194  0.7361  0.0000  0.0848  0.0157  0.0
# 204  1.51711  0.1423  0.0000  0.0208  0.7336  0.0000  0.0862  0.0167  0.0
#
#      Type
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...

# %% [markdown]
# ## 3.3 - Scaling RI (MinMax Scaling)

# %%
glass_RI_scaled = minmax_scaling(glass_RI, columns=['RI']) # Minmax scale RI column.

glass_scaled_wo_RI = glass_oc_scaled.iloc[:,1:].copy() # Copy 'RI' column w/o scaling.

glass_all_scaled = pd.concat([glass_RI_scaled.reset_index(drop=True), 
                              glass_scaled_wo_RI.reset_index(drop=True)], 
                             axis=1)
glass_all_scaled
# Out:
#            RI      Na      Mg      Al      Si       K      Ca      Ba   Fe  \
# 0    0.432836  0.1364  0.0449  0.0110  0.7178  0.0006  0.0875  0.0000  0.0
# 1    0.283582  0.1389  0.0360  0.0136  0.7273  0.0048  0.0783  0.0000  0.0
# 2    0.220808  0.1353  0.0355  0.0154  0.7299  0.0039  0.0778  0.0000  0.0
# 3    0.285777  0.1321  0.0369  0.0129  0.7261  0.0057  0.0822  0.0000  0.0
# 4    0.275241  0.1327  0.0362  0.0124  0.7308  0.0055  0.0807  0.0000  0.0
# ..        ...     ...     ...     ...     ...     ...     ...     ...  ...
# 200  0.223003  0.1414  0.0000  0.0288  0.7261  0.0008  0.0918  0.0106  0.0
# 201  0.250219  0.1492  0.0000  0.0199  0.7306  0.0000  0.0840  0.0159  0.0
# 202  0.417032  0.1436  0.0000  0.0202  0.7342  0.0000  0.0844  0.0164  0.0
# 203  0.235294  0.1438  0.0000  0.0194  0.7361  0.0000  0.0848  0.0157  0.0
# 204  0.261633  0.1423  0.0000  0.0208  0.7336  0.0000  0.0862  0.0167  0.0
#
#      Type
# 0       1
# 1       1
# 2       1
# 3       1
# ...

# %% [markdown]
# ## 3.4 - Normalisation

# %% [markdown]
# Until now we obtained four data sets, three of them are altered, `glass`, `glass_outs_dropped`, `glass_oc_scaled`, and `glass_all_scaled`. Let's obtain normalised versions of those data sets.

# %%
def normaliser(X, features):
    X_norm = []
    
    for feature in features:
        X_bc_transformed, _ = stats.boxcox(X[feature]+1)
        
        X_norm.append(X_bc_transformed)
    X_norm = np.column_stack(X_norm)
    X_norm = pd.DataFrame(data=X_norm, columns=features)
    X_norm = pd.concat([X_norm.reset_index(drop=True), 
                        X['Type'].reset_index(drop=True)], 
                       axis=1)
    
    return X_norm

glass_norm = normaliser(glass, features)
gls_ots_drp_norm = normaliser(glass_outs_dropped, features)
gls_oc_scl_norm = normaliser(glass_oc_scaled, features)
gls_all_scl_norm = normaliser(glass_all_scaled, features)

# %%
for col in glass[features]:
    fig, axes=plt.subplots(figsize=(10, 2), nrows=1, ncols=4)
    
    sns.distplot(glass[col], ax=axes[0], fit=stats.norm)#, label = 'Skew = %.3f' %(glass[col].skew()))
    sns.distplot(gls_ots_drp_norm[col], ax=axes[1], fit=stats.norm)#, label = 'Skew = %.3f' %(gls_ots_drp_norm[col].skew()))
    sns.distplot(gls_oc_scl_norm[col], ax=axes[2], fit=stats.norm)#, label = 'Skew = %.3f' %(gls_oc_scl_norm[col].skew()))
    sns.distplot(gls_all_scl_norm[col], ax=axes[3], fit=stats.norm)#, label = 'Skew = %.3f' %(gls_all_scl_norm[col].skew()))
    
    #plt.legend(loc='best')
    plt.show()

# %% [markdown]
# # 4 - Models <a class="anchor" id="chapter4"></a>

# %% [markdown]
# ## 4.1 - Selecting model(s) and data set

# %% [markdown]
# Above we obtained eight altered data sets. To have an idea, below I am going to make a simple cross-comparison of models and data sets. For the sake of simplicity, I will use the models with their default values.

# %%
models = {'RFC': RandomForestClassifier(), 'ADA': AdaBoostClassifier(),
          'KNN':KNeighborsClassifier(), 'XTC': ExtraTreesClassifier(), 
          'GBS': GradientBoostingClassifier(), 'SVC': SVC(), 'GNB': GaussianNB()}

df_sets = {'glass': glass, 'glass_outs_dropped': glass_outs_dropped, 'glass_oc_scaled': glass_oc_scaled, 'glass_all_scaled': glass_all_scaled, 
           'glass_norm': glass_norm, 'gls_ots_drp_norm': gls_ots_drp_norm, 'gls_oc_scl_norm': gls_oc_scl_norm, 'gls_all_scl_norm': gls_all_scl_norm}

for model in models:
    for dataSet in df_sets:
        
        # Train test split the altered data sets.
        X = df_sets[dataSet].copy() # original data frame is copied to another data frame to avoid data loss
        y = X.pop('Type') # Return item and drop from frame. Recorded into target variable as series object
    
        from sklearn.model_selection import train_test_split
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
        
        # Apply 10 fold cross-validation. 
        cv_results = cross_val_score(models[model], X_train, y_train, cv=10, scoring = 'accuracy', n_jobs=-1)
        
        print('Accuracy score of', model, 'model with data set', dataSet, 'is %.2f' %(np.mean(cv_results)), '(mean values)')
# Out:
# Accuracy score of RFC model with data set glass is 0.76 (mean values)
# Accuracy score of RFC model with data set glass_outs_dropped is 0.79 (mean values)
# Accuracy score of RFC model with data set glass_oc_scaled is 0.80 (mean values)
# Accuracy score of RFC model with data set glass_all_scaled is 0.81 (mean values)
# Accuracy score of RFC model with data set glass_norm is 0.71 (mean values)
# Accuracy score of RFC model with data set gls_ots_drp_norm is 0.74 (mean values)
# Accuracy score of RFC model with data set gls_oc_scl_norm is 0.75 (mean values)
# Accuracy score of RFC model with data set gls_all_scl_norm is 0.80 (mean values)
# Accuracy score of ADA model with data set glass is 0.36 (mean values)
# Accuracy score of ADA model with data set glass_outs_dropped is 0.49 (mean values)
# Accuracy score of ADA model with data set glass_oc_scaled is 0.48 (mean values)
# Accuracy score of ADA model with data set glass_all_scaled is 0.48 (mean values)
# ...

# %% [markdown]
# Instead of a long print list, these result would be produced in a table for visualisation reasons. At this point I am happy to find a room for improvement for myself but I have to come back later for this since it is out of the scope of this kernel.
#
# When one checks the results, it is clear that not all the models perform good, even normalisation sensitive models after normalisation, such as Gaussian Naive Bayes classifier. Inspecting what makes them suffer is also out of the scope of this kernel, but it worths to return back to this topic at some point.
#
# Apparently `RandomForestClassifier` and `ExtraTreesClassifier` performs better than all other methods for each altered data set. It worths to limit our study with these methods.
#
# It also worth to check in which altered data sets these models perform best so one can compare the methods more accurately.

# %%
sk_std_scaler = StandardScaler().fit(X_train[:,1:]) # for all features except RI
sk_minmax_scl = MinMaxScaler().fit(X_train[:,:1]) # for RI

def preprocessor(X):
    A = np.copy(X)
    A[:,:1] = sk_min_max_scaler.transform(X[:,:1])
    A[:,1:] = sk_std_scaler.transform(X[:,1:])
    return A

preprocessor(X_train)

# %%
from sklearn.preprocessing import FunctionTransformer

preprocess_tansformer = FunctionTransformer(preprocessor)

# %%
p1 = Pipeline([('Scaler', preprocess_tansformer),
               ('Linear Reg', LinearRegression())
              ])

p2 = Pipeline([('Scaler', preprocess_tansformer),
               ('KNN Reg', KNeighborsRegressor(n_neighbors=7))
              ])

p3 = Pipeline([('Scaler', preprocess_tansformer),
               ('Random Forest', RandomForestClassifier(n_estimators=10, max_depth=7))
              ])

# %%
def fit_and_print(p, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test ):
    p.fit(X_train, y_train)
    train_preds = p.predict(X_train)
    test_preds = p.predict(X_test)
    print('Train error: ' + str(mean_absolute_error(train_preds, y_train)))
    print('Test error: ' + str(mean_absolute_error(test_preds, y_test)))

fit_and_print(p1)

# %% [markdown]
# # 5 - Results <a class="anchor" id="chapter5"></a>
